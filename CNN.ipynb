# %%
import tensorflow as tf
from tensorflow.keras import datasets,layers,models
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
(x_train,y_train),(x_test,y_test) = datasets.cifar10.load_data()

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
y_train = y_train.reshape(-1,)
y_test = y_test.reshape(-1,)

x_train=x_train/255
x_test=x_test/255

# %%
cnn = models.Sequential([
    layers.Conv2D(filters=20,activation='relu',kernel_size=(3,3),input_shape=(32,32,3)),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(filters=20,activation='relu',kernel_size=(3,3)),
    layers.MaxPooling2D((2,2)),

    layers.Flatten(),
    layers.Dense(64,activation='relu'),
    layers.Dense(10,activation='softmax')
])

# %%
cnn.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
cnn.fit(x_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 42s 26ms/step - accuracy: 0.3621 - loss: 1.7518
# Epoch 2/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 41s 26ms/step - accuracy: 0.5415 - loss: 1.2877
# Epoch 3/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 41s 27ms/step - accuracy: 0.5956 - loss: 1.1515
# Epoch 4/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 43s 27ms/step - accuracy: 0.6273 - loss: 1.0570
# Epoch 5/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 79s 25ms/step - accuracy: 0.6447 - loss: 1.0139
