# %%
import os

# %%
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.7/407.7 kB 23.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.9/296.9 kB 16.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.7 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 27.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.1 MB/s eta 0:00:00
# ...

# %%
from langchain.llms import HuggingFaceHub
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"
llms = HuggingFaceHub(
    repo_id="google/flan-t5-base",
)
# Out:
# <ipython-input-8-0237564a38d1>:4: LangChainDeprecationWarning: The class `HuggingFaceHub` was deprecated in LangChain 0.0.21 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEndpoint``.
#   llms = HuggingFaceHub(

# %%
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

# %%
Prompt_template_course = PromptTemplate(input_variables = ['Courses'],template = "I have completed class 10. I am interested in {Courses}. Could you suggest some good courses or streams to consider?")
course_chain = LLMChain(llm=llms,prompt=Prompt_template_course)
# Out:
# <ipython-input-14-f5f0ec950c87>:2: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   course_chain = LLMChain(llm=llms,prompt=Prompt_template_course)

# %%
from langchain.chains import SimpleSequentialChain

chain = SimpleSequentialChain(chains =[course_chain])

# %%
chain.run('heart')
# Out:
# <ipython-input-16-4826f1743c48>:1: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   chain.run('heart')
# 'adolescent psychology'

# %%
Prompt_template_course = PromptTemplate(input_variables = ['Courses'],template = "I have completed class 10. I am interested in {Courses}. Could you suggest some good courses or streams to consider?")
course_chain = LLMChain(llm=llms,prompt=Prompt_template_course,output_key = 'suggestions')

Prompt_template_suggestion  = PromptTemplate(input_variables = ['suggestions'],template = "Based on my interest in {suggestions}, can you give me more detailed advice on specific courses or career paths I should explore?")
suggestion_chain = LLMChain(llm=llms,prompt=Prompt_template_suggestion)
chain = SimpleSequentialChain(chains =[course_chain])

# %%
from langchain.chains import SequentialChain

,chain = SequentialChain(chains =[course_chain,suggestion_chain],input_variables=['Courses'],output_variables=['suggestions'])

# %%
chain({'courses':'social'})
# Out:
# <ipython-input-19-8abdc4932c8f>:1: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   chain({'Courses':'social'})
# {'Courses': 'social', 'suggestions': 'social studies'}

# %%
# !pip install wikipedia

# %%
# !pip install llm-math
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 10.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 61.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 86.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.8/20.8 MB 73.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.9 MB/s eta 0:00:00
# ...

# %%
from langchain.agents import AgentType,load_tools,initialize_agent
import wikipedia,llm_math
import langchain

tools = load_tools(['wikipedia','llm-math'],llm=llms)
agent = initialize_agent(tools,llm=llms,agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION)

# %%
result=agent.run(' elephant ?')
# Out:
# ---------------------------------------------------------------------------
# OutputParserException                     Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/langchain/agents/agent.py in _iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1362             # Call the LLM to see what to do.
# -> 1363             output = self._action_agent.plan(
#    1364                 intermediate_steps,
#
# /usr/local/lib/python3.10/dist-packages/langchain/agents/agent.py in plan(self, intermediate_steps, callbacks, **kwargs)
#     809         full_output = self.llm_chain.predict(callbacks=callbacks, **full_inputs)
# --> 810         return self.output_parser.parse(full_output)
#     811
#
# /usr/local/lib/python3.10/dist-packages/langchain/agents/mrkl/output_parser.py in parse(self, text)
#      78         if not re.search(r"Action\s*\d*\s*:[\s]*(.*?)", text, re.DOTALL):
# ...

# %%
result
# Out:
# 'Agent stopped due to iteration limit or time limit.'
